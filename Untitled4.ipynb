# %% [markdown]
# <a href="https://colab.research.google.com/github/reddyniyati3938/random-password-generetor/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

def generate_password(length=12, use_digits=True, use_symbols=True):
    letters = string.ascii_letters
    digits = string.digits
    symbols = string.punctuation

    characters = letters
    if use_digits:
        characters += digits
    if use_symbols:
        characters += symbols

    if length < 4:
        raise ValueError("Password length should be at least 4 characters.")

    password = "".join(random.choice(characters) for _ in range(length))
    return password


def main():
    print("=== PASSWORD GENERATOR ===")

    # Ask for length
    length = int(input("Enter password length: "))

    # Ask for digit and symbol choices
    use_digits = input("Include digits? (y/n): ").lower() == 'y'
    use_symbols = input("Include symbols? (y/n): ").lower() == 'y'

    # Generate password
    password = generate_password(length, use_digits, use_symbols)

    print("\nYour generated password:")
    print(password)


if __name__ == "__main__":
    main()
# Out:
# === PASSWORD GENERATOR ===
# Enter password length: 12
# Include digits? (y/n): y
# Include symbols? (y/n): n
#
# Your generated password:
# Eu1nOydV6SVh
